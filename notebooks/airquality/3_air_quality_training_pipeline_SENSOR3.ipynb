# %%
import sys
from pathlib import Path

def is_google_colab() -> bool:
    if "google.colab" in str(get_ipython()):
        return True
    return False

def clone_repository() -> None:
    # !git clone https://github.com/featurestorebook/mlfs-book.git
    # %cd mlfs-book

def install_dependencies() -> None:
    # !pip install --upgrade uv
    # !uv pip install --all-extras --system --requirement pyproject.toml

if is_google_colab():
    clone_repository()
    install_dependencies()
    root_dir = str(Path().absolute())
    print("Google Colab environment")
else:
    root_dir = Path().absolute()
    # Strip ~/notebooks/ccfraud from PYTHON_PATH if notebook started in one of these subdirectories
    if root_dir.parts[-1:] == ('airquality',):
        root_dir = Path(*root_dir.parts[:-1])
    if root_dir.parts[-1:] == ('notebooks',):
        root_dir = Path(*root_dir.parts[:-1])
    root_dir = str(root_dir) 
    print("Local environment")

# Add the root directory to the `PYTHONPATH` to use the `recsys` Python module from the notebook.
if root_dir not in sys.path:
    sys.path.append(root_dir)
print(f"Added the following directory to the PYTHONPATH: {root_dir}")
    
# Set the environment variables from the file <root_dir>/.env
from mlfs import config_Sensor_3
settings = config_Sensor_3.HopsworksSettings(_env_file=f"{root_dir}/.env")
# Out:
# Local environment
# Added the following directory to the PYTHONPATH: /Users/karen/mlfs-book
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# HopsworksSettings initialized!

# %% [markdown]
# # <span style="font-width:bold; font-size: 3rem; color:#333;">Training Pipeline</span>
#
# ## 🗒️ This notebook is divided into the following sections:
#
# 1. Select features for the model and create a Feature View with the selected features
# 2. Create training data using the feature view
# 3. Train model
# 4. Evaluate model performance
# 5. Save model to model registry

# %% [markdown]
# ### <span style='color:#ff5f27'> 📝 Imports

# %%
import os
from datetime import datetime, timedelta
import pandas as pd
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from xgboost import plot_importance
from sklearn.metrics import mean_squared_error, r2_score
import hopsworks
import json
from mlfs.airquality import util

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## <span style="color:#ff5f27;"> 📡 Connect to Hopsworks Feature Store </span>

# %%
# Check if HOPSWORKS_API_KEY env variable is set or if it is set in ~/.env
if settings.HOPSWORKS_API_KEY is not None:
    api_key = settings.HOPSWORKS_API_KEY.get_secret_value()
    os.environ['HOPSWORKS_API_KEY'] = api_key
project = hopsworks.login(engine="python")
fs = project.get_feature_store() 

secrets = hopsworks.get_secrets_api()
location_str = secrets.get_secret("SENSOR3_LOCATION_JSON").value
location = json.loads(location_str)
country=location['country']
city=location['city']
street=location['street']
# Out:
# 2025-11-15 21:43:04,577 INFO: Initializing external client
# 2025-11-15 21:43:04,578 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-11-15 21:43:06,236 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1279151

# %%
# Retrieve feature groups
air_quality_fg = fs.get_feature_group(
    name='air_quality_lagged_sensor_3',
    version=1,
)
weather_fg = fs.get_feature_group(
    name='weather_sensor',
    version=1,
)

# %% [markdown]
# ---
#
# ## <span style="color:#ff5f27;"> 🖍 Feature View Creation and Retrieving </span>

# %%
# Select features for training data.
# Retrieve lags
selected_features = air_quality_fg.select(['pm25', 'date', 'lag_1', 'lag_2', 'lag_3']).join(weather_fg.select_features(), on=['city'])
# Out:
# 2025-11-15 21:43:09,800 INFO: Using ['temperature_2m_mean', 'apparent_temperature_mean', 'dewpoint_2m_mean', 'precipitation_sum', 'rain_sum', 'snowfall_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant', 'shortwave_radiation_sum', 'et0_fao_evapotranspiration'] from feature group `weather_sensor` as features for the query. To include primary key and event time use `select_all`.

# %% [markdown]
# ### Feature Views
#
# `Feature Views` are selections of features from different **Feature Groups** that make up the input and output API (or schema) for a model. A **Feature Views** can create **Training Data** and also be used in Inference to retrieve inference data.
#
# The Feature Views allows a schema in form of a query with filters, defining a model target feature/label and additional transformation functions (declarative feature encoding).
#
# In order to create Feature View we can use `FeatureStore.get_or_create_feature_view()` method.
#
# You can specify the following parameters:
#
# - `name` - name of a feature group.
#
# - `version` - version of a feature group.
#
# - `labels`- our target variable.
#
# - `transformation_functions` - declarative feature encoding (not used here)
#
# - `query` - selected features/labels for the model

# %%
feature_view = fs.get_or_create_feature_view(
    name='air_quality_lagged_sensor_3',
    description="weather features with air quality as the target",
    version=1,
    labels=['pm25'],
    query=selected_features,
)

# %%
a = selected_features.read()
a
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.69s)
#        pm25                      date  lag_1  lag_2  lag_3  \
# 0      2.85 2021-01-03 00:00:00+00:00   3.40   6.07  17.77
# 1      2.72 2021-01-04 00:00:00+00:00   2.85   3.40   6.07
# 2      4.11 2021-01-05 00:00:00+00:00   2.72   2.85   3.40
# 3      3.42 2021-01-06 00:00:00+00:00   4.11   2.72   2.85
# 4      9.07 2021-01-07 00:00:00+00:00   3.42   4.11   2.72
# ...     ...                       ...    ...    ...    ...
# 1495  13.00 2025-11-10 00:00:00+00:00   4.59   3.49   7.75
# 1496   3.14 2025-11-12 00:00:00+00:00  13.00   4.59   3.49
# 1497   6.87 2025-11-13 00:00:00+00:00   3.14  13.00   4.59
# 1498   7.30 2025-11-14 00:00:00+00:00   6.87   3.14  13.00
# 1499  47.00 2025-11-15 00:00:00+00:00   7.30   6.87   3.14
#
#       temperature_2m_mean  apparent_temperature_mean  dewpoint_2m_mean  \
# 0                8.086667                   4.820736          5.617916
# 1                7.395000                   5.077226          4.813750
# 2                7.824167                   4.853842          5.861667
# 3                7.815834                   5.263431          3.747083
# 4                5.480417                   3.034517          3.395000
# ...                   ...                        ...               ...
# 1495            12.388749                  11.399755          8.847083
# 1496            12.130416                  10.948205          7.595001
# 1497            12.613750                  11.775219          8.897083
# 1498            13.253333                  12.498933          9.982501
# 1499            20.950001                  19.937057         13.145895
#
#       precipitation_sum   rain_sum  snowfall_sum  wind_speed_10m_max  \
# 0              4.099999   4.099999           0.0           21.611996
# 1              3.500000   3.500000           0.0           12.889810
# 2             21.199999  21.199999           0.0           24.203140
# 3              2.000000   2.000000           0.0           14.529915
# 4              2.400000   2.400000           0.0            8.854829
# ...                 ...        ...           ...                 ...
# 1495           0.000000   0.000000           0.0            7.814985
# 1496           0.000000   0.000000           0.0            7.452086
# 1497           0.000000   0.000000           0.0            8.305396
# 1498           0.000000   0.000000           0.0           11.341428
# 1499           0.000000   0.000000           0.0           13.797912
#
#       wind_direction_10m_dominant  shortwave_radiation_sum  \
# 0                      145.728409                     3.63
# 1                      144.851257                     6.54
# 2                      159.851990                     1.49
# 3                      188.790451                     5.67
# 4                       70.934311                     2.40
# ...                           ...                      ...
# 1495                    31.873682                    10.62
# 1496                    52.888248                    10.43
# 1497                    63.237240                    10.38
# 1498                   113.593491                     9.14
# 1499                   187.495758                   416.00
#
#       et0_fao_evapotranspiration
# 0                       0.700368
# 1                       0.830209
# 2                       0.464811
# 3                       0.876132
# 4                       0.414483
# ...                          ...
# 1495                    1.465502
# 1496                    1.458708
# 1497                    1.468767
# 1498                    1.475651
# 1499                    0.270081
#
# [1500 rows x 15 columns]

# %% [markdown]
# ## <span style="color:#ff5f27;">🪝 Split the training data into train/test data sets </span>
#
# We use a time-series split here, with training data before this date `start_date_test_data` and test data after this date

# %%
start_date_test_data = "2025-05-01"
# Convert string to datetime object
test_start = datetime.strptime(start_date_test_data, "%Y-%m-%d")

# %%
X_train, X_test, y_train, y_test = feature_view.train_test_split(
    test_start=test_start
)
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (2.15s)

# %%
X_train
# Out:
#                            date  lag_1  lag_2  lag_3  temperature_2m_mean  \
# 0     2021-01-03 00:00:00+00:00   3.40   6.07  17.77             8.086667
# 1     2021-01-04 00:00:00+00:00   2.85   3.40   6.07             7.395000
# 2     2021-01-05 00:00:00+00:00   2.72   2.85   3.40             7.824167
# 3     2021-01-06 00:00:00+00:00   4.11   2.72   2.85             7.815834
# 4     2021-01-07 00:00:00+00:00   3.42   4.11   2.72             5.480417
# ...                         ...    ...    ...    ...                  ...
# 1305  2025-04-25 00:00:00+00:00   7.15   2.50   2.13            15.470000
# 1306  2025-04-26 00:00:00+00:00   2.09   7.15   2.50            16.126249
# 1307  2025-04-27 00:00:00+00:00   1.30   2.09   7.15            16.719999
# 1308  2025-04-28 00:00:00+00:00   3.83   1.30   2.09            16.617918
# 1309  2025-04-30 00:00:00+00:00  10.00   3.83   1.30            18.311666
#
#       apparent_temperature_mean  dewpoint_2m_mean  precipitation_sum  \
# 0                      4.820736          5.617916           4.099999
# 1                      5.077226          4.813750           3.500000
# 2                      4.853842          5.861667          21.199999
# 3                      5.263431          3.747083           2.000000
# 4                      3.034517          3.395000           2.400000
# ...                         ...               ...                ...
# 1305                  15.691833         12.480416           3.100000
# 1306                  16.051447         11.253333           0.500000
# 1307                  17.000061         12.317918           1.500000
# 1308                  17.091251         13.369999           7.100000
# 1309                  19.001345         13.242917           0.000000
#
#        rain_sum  snowfall_sum  wind_speed_10m_max  \
# 0      4.099999           0.0           21.611996
# 1      3.500000           0.0           12.889810
# 2     21.199999           0.0           24.203140
# 3      2.000000           0.0           14.529915
# 4      2.400000           0.0            8.854829
# ...         ...           ...                 ...
# 1305   3.100000           0.0           11.720751
# 1306   0.500000           0.0            9.028754
# 1307   1.500000           0.0           11.841756
# 1308   7.100000           0.0            8.089993
# 1309   0.000000           0.0            9.423820
#
#       wind_direction_10m_dominant  shortwave_radiation_sum  \
# 0                      145.728409                 3.630000
# 1                      144.851257                 6.540000
# 2                      159.851990                 1.490000
# 3                      188.790451                 5.670000
# 4                       70.934311                 2.400000
# ...                           ...                      ...
# 1305                   219.882660                20.730000
# 1306                    14.967858                23.469999
# 1307                    62.655567                21.610001
# 1308                    37.217880                19.820000
# 1309                   268.667786                24.260000
#
#       et0_fao_evapotranspiration
# 0                       0.700368
# 1                       0.830209
# 2                       0.464811
# 3                       0.876132
# 4                       0.414483
# ...                          ...
# 1305                    3.281923
# 1306                    3.874317
# 1307                    3.691100
# 1308                    3.340368
# 1309                    4.304651
#
# [1310 rows x 14 columns]

# %%
X_features = X_train.drop(columns=['date'])
X_test_features = X_test.drop(columns=['date'])

# %%
y_train
# Out:
#        pm25
# 0      2.85
# 1      2.72
# 2      4.11
# 3      3.42
# 4      9.07
# ...     ...
# 1305   2.09
# 1306   1.30
# 1307   3.83
# 1308  10.00
# 1309   3.28
#
# [1310 rows x 1 columns]

# %% [markdown]
# The `Feature View` is now saved in Hopsworks and you can retrieve it using `FeatureStore.get_feature_view(name='...', version=1)`.

# %% [markdown]
# ---

# %% [markdown]
# ## <span style="color:#ff5f27;">🧬 Modeling</span>
#
# We will train a regression model to predict pm25 using our 4 features (wind_speed, wind_dir, temp, precipitation)

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint

param_distributions = {
    "n_estimators": randint(200, 1200),
    "max_depth": randint(3, 12),
    "learning_rate": uniform(0.01, 0.2),
    "subsample": uniform(0.5, 0.5),
    "colsample_bytree": uniform(0.5, 0.5),
    "gamma": uniform(0, 5)
}

xgb = XGBRegressor(objective="reg:squarederror")

from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV

tscv = TimeSeriesSplit(n_splits=5)

random_search = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_distributions,
    n_iter=50,
    cv=tscv,  # Use TimeSeriesSplit
    scoring="neg_mean_squared_error",
    verbose=2,
    n_jobs=-1,
    random_state=42
)


random_search.fit(X_features, y_train)

print("Best parameters:", random_search.best_params_)
best_model = random_search.best_estimator_
xgb_regressor = best_model
xgb_regressor.fit(X_features, y_train)

y_pred = xgb_regressor.predict(X_test_features)

mse = mean_squared_error(y_test.iloc[:,0], y_pred)
r2 = r2_score(y_test.iloc[:,0], y_pred)

print("MSE:", mse)
print("R2:", r2)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters: {'colsample_bytree': 0.5507357714330161, 'gamma': 3.317508845540279, 'learning_rate': 0.011012316769243738, 'max_depth': 4, 'n_estimators': 905, 'subsample': 0.8459475988463466}
# MSE: 13.354266
# R2: 0.1959987963228681

# %%
# Predicting target values on the test set
y_pred = xgb_regressor.predict(X_test_features)

# Calculating Mean Squared Error (MSE) using sklearn
mse = mean_squared_error(y_test.iloc[:,0], y_pred)
print("MSE:", mse)

# Calculating R squared using sklearn
r2 = r2_score(y_test.iloc[:,0], y_pred)
print("R squared:", r2)
# Out:
# MSE: 13.354266
# R squared: 0.1959987963228681

# %%
df = y_test
df['predicted_pm25'] = y_pred

# %%
df['date'] = X_test['date']
df = df.sort_values(by=['date'])
df.head(5)
# Out:
#       pm25  predicted_pm25                       date
# 1310  6.38        4.164878  2025-05-01 00:00:00+00:00
# 1311  3.25        6.908959  2025-05-04 00:00:00+00:00
# 1312  3.37        2.900985  2025-05-05 00:00:00+00:00
# 1313  5.65        2.969790  2025-05-06 00:00:00+00:00
# 1314  2.15        4.816682  2025-05-07 00:00:00+00:00

# %%
# Creating a directory for the model artifacts if it doesn't exist
model_dir = "air_quality_model/sensor3"
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
images_dir = model_dir + "/images"
if not os.path.exists(images_dir):
    os.mkdir(images_dir)

# %%
file_path = images_dir + "/pm25_hindcast.png"
plt = util.plot_air_quality_forecast(city, street, df, file_path, hindcast=True) 
plt.show()

# %%
# Plotting feature importances using the plot_importance function from XGBoost
plot_importance(xgb_regressor)
#plot_importance(forecaster)
feature_importance_path = images_dir + "/feature_importance.png"
plt.savefig(feature_importance_path)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:#ff5f27'>🗄 Model Registry</span>
#
# One of the features in Hopsworks is the model registry. This is where you can store different versions of models and compare their performance. Models from the registry can then be served as API endpoints.

# %%
# Saving the XGBoost regressor object as a json file in the model directory
#xgb_regressor.save_model(model_dir + "/model.json")
xgb_regressor.save_model(model_dir + "/model_3.json")

# %%
res_dict = { 
        "MSE": str(mse),
        "R squared": str(r2),
    }

# %%
mr_sensor_3 = project.get_model_registry()

# Creating a Python model in the model registry named 'air_quality_xgboost_model'

aq_model_sensor_3 = mr_sensor_3.python.create_model(
    name="air_quality_xgboost_model_with_lags_sensor_3", 
    metrics= res_dict,
    feature_view=feature_view,
    description="Air Quality (PM2.5) predictor for sensor 3",
)

# Saving the model artifacts to the 'air_quality_model' directory in the model registry
aq_model_sensor_3.save(model_dir)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Uploading /Users/karen/mlfs-book/notebooks/airquality/air_quality_model/sensor3/model.json: 0.000%|          |…
# Uploading /Users/karen/mlfs-book/notebooks/airquality/air_quality_model/sensor3/model_3.json: 0.000%|         …
# Uploading /Users/karen/mlfs-book/notebooks/airquality/air_quality_model/sensor3/images/feature_importance.png:…
# Uploading /Users/karen/mlfs-book/notebooks/airquality/air_quality_model/sensor3/images/pm25_hindcast.png: 0.00…
# Uploading /Users/karen/mlfs-book/notebooks/airquality/model_schema.json: 0.000%|          | 0/1246 elapsed<00:…
# Model created, explore it at https://c.app.hopsworks.ai:443/p/1279151/models/air_quality_xgboost_model_with_lags_sensor_3/7
# Model(name: 'air_quality_xgboost_model_with_lags_sensor_3', version: 7)
# [CV] END colsample_bytree=0.5282057895135501, gamma=3.609993861334124, learning_rate=0.19771054180315006, max_depth=4, n_estimators=391, subsample=0.9961057796456088; total time=   0.0s
# [CV] END colsample_bytree=0.8087407548138583, gamma=3.0582658024414044, learning_rate=0.011413261043943482, max_depth=11, n_estimators=760, subsample=0.7623873301291946; total time=   0.4s
# [CV] END colsample_bytree=0.5924272277627636, gamma=4.847923138822793, learning_rate=0.16502656467222293, max_depth=4, n_estimators=401, subsample=0.9474136752138245; total time=   0.0s
# [CV] END colsample_bytree=0.7989499894055425, gamma=4.609371175115584, learning_rate=0.0276985004103839, max_depth=9, n_estimators=451, subsample=0.522613644455269; total time=   0.2s
# [CV] END colsample_bytree=0.8861223846483287, gamma=0.993578407670862, learning_rate=0.01110442342472048, max_depth=5, n_estimators=792, subsample=0.855670976374325; total time=   0.4s
# [CV] END colsample_bytree=0.7542853455823514, gamma=4.537832369630465, learning_rate=0.059858445829774995, max_depth=6, n_estimators=724, subsample=0.5384899549143964; total time=   0.2s
# [CV] END colsample_bytree=0.9534142207728771, gamma=1.3606612469231765, learning_rate=0.13953802410827248, max_depth=11, n_estimators=827, subsample=0.6762844281670846; total time=   0.1s
# [CV] END colsample_bytree=0.668807585701814, gamma=4.714548519562596, learning_rate=0.07464058640415104, max_depth=10, n_estimators=432, subsample=0.7019180855290204; total time=   0.1s
# [CV] END colsample_bytree=0.5324461235544908, gamma=1.2695770696717235, learning_rate=0.05937521256772024, max_depth=9, n_estimators=585, subsample=0.856135294962221; total time=   0.2s
# [CV] END colsample_bytree=0.9015698781899479, gamma=2.351503172230192, learning_rate=0.2066846281789686, max_depth=8, n_estimators=1106, subsample=0.908215936609692; total time=   0.2s
# [CV] END colsample_bytree=0.970261632244802, gamma=1.9878601054376115, learning_rate=0.11355027010549602, max_depth=10, n_estimators=840, subsample=0.8378450585196404; total time=   0.1s
# [CV] END colsample_bytree=0.9486078789766634, gamma=4.502090285816652, learning_rate=0.1366202914546536, max_depth=11, n_estimators=432, subsample=0.6746047873063304; total time=   0.1s
# [CV] END colsample_bytree=0.5420699824975244, gamma=0.8081435704730688, learning_rate=0.18971083770541586, max_depth=6, n_estimators=453, subsample=0.5045985258083148; total time=   0.1s
# [CV] END colsample_bytree=0.8259806297513003, gamma=1.121346547302799, learning_rate=0.15243584426950718, max_depth=3, n_estimators=597, subsample=0.6626998490796339; total time=   0.1s
# [CV] END colsample_bytree=0.9460232775885566, gamma=3.1556931299863145, learning_rate=0.1689622607083297, max_depth=3, n_estimators=483, subsample=0.8344620298315498; total time=   0.1s
# [CV] END colsample_bytree=0.5218018858772169, gamma=4.972752553986705, learning_rate=0.10398890279818859, max_depth=7, n_estimators=717, subsample=0.6850793501277221; total time=   0.0s
# [CV] END colsample_bytree=0.5077283082644337, gamma=4.641592812938627, learning_rate=0.09563682966346286, max_depth=7, n_estimators=806, subsample=0.9818099885446264; total time=   0.1s
# [CV] END colsample_bytree=0.5847463733430462, gamma=2.784006312291751, learning_rate=0.19723095483215622, max_depth=5, n_estimators=1071, subsample=0.535208065424772; total time=   0.1s
# [CV] END colsample_bytree=0.5499874579090014, gamma=2.2962444598293357, learning_rate=0.07674172222780437, max_depth=10, n_estimators=863, subsample=0.8254442364744264; total time=   0.2s
# [CV] END colsample_bytree=0.9744427686266666, gamma=4.828160165372797, learning_rate=0.17167946962329225, max_depth=11, n_estimators=545, subsample=0.5488360570031919; total time=   0.1s
# [CV] END colsample_bytree=0.8421165132560784, gamma=2.2007624686980067, learning_rate=0.03440764696895577, max_depth=10, n_estimators=1142, subsample=0.5866823267538861; total time=   0.2s
# [CV] END colsample_bytree=0.6626651653816322, gamma=1.9433864484474102, learning_rate=0.06426980635477918, max_depth=7, n_estimators=991, subsample=0.6783766633467947; total time=   0.1s
# [CV] END colsample_bytree=0.6626651653816322, gamma=1.9433864484474102, learning_rate=0.06426980635477918, max_depth=7, n_estimators=991, subsample=0.6783766633467947; total time=   0.2s
# [CV] END colsample_bytree=0.811649063413779, gamma=1.654490124263246, learning_rate=0.02271167005720473, max_depth=9, n_estimators=773, subsample=0.6625916610133735; total time=   0.2s
# [CV] END colsample_bytree=0.7137705091792748, gamma=0.12709563372047594, learning_rate=0.031578285398660894, max_depth=9, n_estimators=440, subsample=0.6571779905381634; total time=   0.2s
# [CV] END colsample_bytree=0.6448757264568841, gamma=0.8061064362700221, learning_rate=0.19593953046851464, max_depth=11, n_estimators=845, subsample=0.7282672852414551; total time=   0.1s
# [CV] END colsample_bytree=0.9534142207728771, gamma=1.3606612469231765, learning_rate=0.13953802410827248, max_depth=11, n_estimators=827, subsample=0.6762844281670846; total time=   0.2s
# [CV] END colsample_bytree=0.5740434649766999, gamma=4.98870242524471, learning_rate=0.063356202855057, max_depth=4, n_estimators=841, subsample=0.7055185066591156; total time=   0.1s
# [CV] END colsample_bytree=0.9928252270553004, gamma=1.2102763575575022, learning_rate=0.14442710948117574, max_depth=10, n_estimators=322, subsample=0.621079969138713; total time=   0.2s
# [CV] END colsample_bytree=0.6101205237827741, gamma=3.555747662190089, learning_rate=0.1719002092279431, max_depth=6, n_estimators=1063, subsample=0.5480882755457104; total time=   0.1s
# [CV] END colsample_bytree=0.9086111001006079, gamma=2.7760040579973118, learning_rate=0.1159301156712013, max_depth=4, n_estimators=1096, subsample=0.5465513839029497; total time=   0.2s
# [CV] END colsample_bytree=0.8732457025590121, gamma=3.2481644952360735, learning_rate=0.1798446820988356, max_depth=3, n_estimators=839, subsample=0.7841543016677358; total time=   0.1s
# [CV] END colsample_bytree=0.9460232775885566, gamma=3.1556931299863145, learning_rate=0.1689622607083297, max_depth=3, n_estimators=483, subsample=0.8344620298315498; total time=   0.1s
# [CV] END colsample_bytree=0.5218018858772169, gamma=4.972752553986705, learning_rate=0.10398890279818859, max_depth=7, n_estimators=717, subsample=0.6850793501277221; total time=   0.1s
# [CV] END colsample_bytree=0.5847463733430462, gamma=2.784006312291751, learning_rate=0.19723095483215622, max_depth=5, n_estimators=1071, subsample=0.535208065424772; total time=   0.1s
# [CV] END colsample_bytree=0.848507870497634, gamma=3.5124204199355464, learning_rate=0.08189823024395103, max_depth=9, n_estimators=737, subsample=0.9050566973395904; total time=   0.1s
# [CV] END colsample_bytree=0.5499874579090014, gamma=2.2962444598293357, learning_rate=0.07674172222780437, max_depth=10, n_estimators=863, subsample=0.8254442364744264; total time=   0.1s
# [CV] END colsample_bytree=0.6999304858576277, gamma=0.23332831606807714, learning_rate=0.20475110376829186, max_depth=5, n_estimators=1075, subsample=0.7571172192068059; total time=   0.1s
# [CV] END colsample_bytree=0.9744427686266666, gamma=4.828160165372797, learning_rate=0.17167946962329225, max_depth=11, n_estimators=545, subsample=0.5488360570031919; total time=   0.1s
# [CV] END colsample_bytree=0.6955303037866204, gamma=0.9111804389403116, learning_rate=0.16107228206353053, max_depth=8, n_estimators=765, subsample=0.7733551396716398; total time=   0.1s
# [CV] END colsample_bytree=0.5924272277627636, gamma=4.847923138822793, learning_rate=0.16502656467222293, max_depth=4, n_estimators=401, subsample=0.9474136752138245; total time=   0.0s
# [CV] END colsample_bytree=0.7989499894055425, gamma=4.609371175115584, learning_rate=0.0276985004103839, max_depth=9, n_estimators=451, subsample=0.522613644455269; total time=   0.2s
# [CV] END colsample_bytree=0.6404672548436904, gamma=2.7134804157912424, learning_rate=0.03818484499495253, max_depth=3, n_estimators=1056, subsample=0.9934434683002586; total time=   0.1s
# [CV] END colsample_bytree=0.811649063413779, gamma=1.654490124263246, learning_rate=0.02271167005720473, max_depth=9, n_estimators=773, subsample=0.6625916610133735; total time=   0.5s
# [CV] END colsample_bytree=0.6092202186084168, gamma=2.082549739351831, learning_rate=0.18665605178377367, max_depth=9, n_estimators=547, subsample=0.6781489190384875; total time=   0.1s
# [CV] END colsample_bytree=0.9534142207728771, gamma=1.3606612469231765, learning_rate=0.13953802410827248, max_depth=11, n_estimators=827, subsample=0.6762844281670846; total time=   0.1s
# [CV] END colsample_bytree=0.668807585701814, gamma=4.714548519562596, learning_rate=0.07464058640415104, max_depth=10, n_estimators=432, subsample=0.7019180855290204; total time=   0.1s
# [CV] END colsample_bytree=0.5165253664502742, gamma=1.725356240133415, learning_rate=0.13687026894027277, max_depth=4, n_estimators=252, subsample=0.7447263801387816; total time=   0.1s
# [CV] END colsample_bytree=0.9015698781899479, gamma=2.351503172230192, learning_rate=0.2066846281789686, max_depth=8, n_estimators=1106, subsample=0.908215936609692; total time=   0.2s
# [CV] END colsample_bytree=0.8676080596203861, gamma=1.0453581036885684, learning_rate=0.11828959476551316, max_depth=5, n_estimators=462, subsample=0.8299920230170895; total time=   0.1s
# [CV] END colsample_bytree=0.9086111001006079, gamma=2.7760040579973118, learning_rate=0.1159301156712013, max_depth=4, n_estimators=1096, subsample=0.5465513839029497; total time=   0.1s
# [CV] END colsample_bytree=0.5507357714330161, gamma=3.317508845540279, learning_rate=0.011012316769243738, max_depth=4, n_estimators=905, subsample=0.8459475988463466; total time=   0.2s
# [CV] END colsample_bytree=0.9460232775885566, gamma=3.1556931299863145, learning_rate=0.1689622607083297, max_depth=3, n_estimators=483, subsample=0.8344620298315498; total time=   0.1s
# [CV] END colsample_bytree=0.5218018858772169, gamma=4.972752553986705, learning_rate=0.10398890279818859, max_depth=7, n_estimators=717, subsample=0.6850793501277221; total time=   0.1s
# [CV] END colsample_bytree=0.6044593588076801, gamma=3.355717584120253, learning_rate=0.08172935625923278, max_depth=4, n_estimators=1185, subsample=0.8703843088771022; total time=   0.1s
# [CV] END colsample_bytree=0.5499874579090014, gamma=2.2962444598293357, learning_rate=0.07674172222780437, max_depth=10, n_estimators=863, subsample=0.8254442364744264; total time=   0.1s
# [CV] END colsample_bytree=0.8087407548138583, gamma=3.0582658024414044, learning_rate=0.011413261043943482, max_depth=11, n_estimators=760, subsample=0.7623873301291946; total time=   0.7s
# [CV] END colsample_bytree=0.8950877702656028, gamma=3.029799873905057, learning_rate=0.19526017570266982, max_depth=11, n_estimators=227, subsample=0.9315517129377968; total time=   0.1s
# [CV] END colsample_bytree=0.864803089169032, gamma=3.1877873567760657, learning_rate=0.18744254851526532, max_depth=3, n_estimators=938, subsample=0.5597971229691509; total time=   0.1s
# [CV] END colsample_bytree=0.864803089169032, gamma=3.1877873567760657, learning_rate=0.18744254851526532, max_depth=3, n_estimators=938, subsample=0.5597971229691509; total time=   0.2s
# [CV] END colsample_bytree=0.7137705091792748, gamma=0.12709563372047594, learning_rate=0.031578285398660894, max_depth=9, n_estimators=440, subsample=0.6571779905381634; total time=   0.5s
# [CV] END colsample_bytree=0.5165253664502742, gamma=1.725356240133415, learning_rate=0.13687026894027277, max_depth=4, n_estimators=252, subsample=0.7447263801387816; total time=   0.0s
# [CV] END colsample_bytree=0.5165253664502742, gamma=1.725356240133415, learning_rate=0.13687026894027277, max_depth=4, n_estimators=252, subsample=0.7447263801387816; total time=   0.1s
# [CV] END colsample_bytree=0.8991725624922755, gamma=0.7535877198271473, learning_rate=0.11163975534814373, max_depth=5, n_estimators=859, subsample=0.6629794526009424; total time=   0.1s
# [CV] END colsample_bytree=0.6101205237827741, gamma=3.555747662190089, learning_rate=0.1719002092279431, max_depth=6, n_estimators=1063, subsample=0.5480882755457104; total time=   0.1s
# [CV] END colsample_bytree=0.9086111001006079, gamma=2.7760040579973118, learning_rate=0.1159301156712013, max_depth=4, n_estimators=1096, subsample=0.5465513839029497; total time=   0.1s
# [CV] END colsample_bytree=0.8629778394351197, gamma=4.485551299762886, learning_rate=0.18741728485302347, max_depth=10, n_estimators=872, subsample=0.8210158230771438; total time=   0.1s
# [CV] END colsample_bytree=0.5420699824975244, gamma=0.8081435704730688, learning_rate=0.18971083770541586, max_depth=6, n_estimators=453, subsample=0.5045985258083148; total time=   0.1s
# [CV] END colsample_bytree=0.8732457025590121, gamma=3.2481644952360735, learning_rate=0.1798446820988356, max_depth=3, n_estimators=839, subsample=0.7841543016677358; total time=   0.1s
# [CV] END colsample_bytree=0.5468373839140462, gamma=1.8385790152971677, learning_rate=0.06304047353634509, max_depth=8, n_estimators=429, subsample=0.6965488623333802; total time=   0.1s
# [CV] END colsample_bytree=0.5077283082644337, gamma=4.641592812938627, learning_rate=0.09563682966346286, max_depth=7, n_estimators=806, subsample=0.9818099885446264; total time=   0.1s
# [CV] END colsample_bytree=0.5847463733430462, gamma=2.784006312291751, learning_rate=0.19723095483215622, max_depth=5, n_estimators=1071, subsample=0.535208065424772; total time=   0.1s
# [CV] END colsample_bytree=0.6872700594236812, gamma=4.75357153204958, learning_rate=0.15639878836228102, max_depth=7, n_estimators=814, subsample=0.7229163764267956; total time=   0.1s
# [CV] END colsample_bytree=0.8087407548138583, gamma=3.0582658024414044, learning_rate=0.011413261043943482, max_depth=11, n_estimators=760, subsample=0.7623873301291946; total time=   0.6s
# [CV] END colsample_bytree=0.6404672548436904, gamma=2.7134804157912424, learning_rate=0.03818484499495253, max_depth=3, n_estimators=1056, subsample=0.9934434683002586; total time=   0.1s
# [CV] END colsample_bytree=0.811649063413779, gamma=1.654490124263246, learning_rate=0.02271167005720473, max_depth=9, n_estimators=773, subsample=0.6625916610133735; total time=   0.1s
# [CV] END colsample_bytree=0.8566223936114975, gamma=3.803925243084487, learning_rate=0.12225543951389925, max_depth=9, n_estimators=994, subsample=0.7613664146909971; total time=   0.1s
# [CV] END colsample_bytree=0.7137705091792748, gamma=0.12709563372047594, learning_rate=0.031578285398660894, max_depth=9, n_estimators=440, subsample=0.6571779905381634; total time=   0.6s
# [CV] END colsample_bytree=0.9928252270553004, gamma=1.2102763575575022, learning_rate=0.14442710948117574, max_depth=10, n_estimators=322, subsample=0.621079969138713; total time=   0.2s
# [CV] END colsample_bytree=0.970261632244802, gamma=1.9878601054376115, learning_rate=0.11355027010549602, max_depth=10, n_estimators=840, subsample=0.8378450585196404; total time=   0.2s
# [CV] END colsample_bytree=0.8629778394351197, gamma=4.485551299762886, learning_rate=0.18741728485302347, max_depth=10, n_estimators=872, subsample=0.8210158230771438; total time=   0.1s
# [CV] END colsample_bytree=0.8732457025590121, gamma=3.2481644952360735, learning_rate=0.1798446820988356, max_depth=3, n_estimators=839, subsample=0.7841543016677358; total time=   0.1s
# [CV] END colsample_bytree=0.5468373839140462, gamma=1.8385790152971677, learning_rate=0.06304047353634509, max_depth=8, n_estimators=429, subsample=0.6965488623333802; total time=   0.1s
# [CV] END colsample_bytree=0.5218018858772169, gamma=4.972752553986705, learning_rate=0.10398890279818859, max_depth=7, n_estimators=717, subsample=0.6850793501277221; total time=   0.1s
# [CV] END colsample_bytree=0.5847463733430462, gamma=2.784006312291751, learning_rate=0.19723095483215622, max_depth=5, n_estimators=1071, subsample=0.535208065424772; total time=   0.1s
# [CV] END colsample_bytree=0.6872700594236812, gamma=4.75357153204958, learning_rate=0.15639878836228102, max_depth=7, n_estimators=814, subsample=0.7229163764267956; total time=   0.1s
# [CV] END colsample_bytree=0.8087407548138583, gamma=3.0582658024414044, learning_rate=0.011413261043943482, max_depth=11, n_estimators=760, subsample=0.7623873301291946; total time=   0.9s
# [CV] END colsample_bytree=0.8566223936114975, gamma=3.803925243084487, learning_rate=0.12225543951389925, max_depth=9, n_estimators=994, subsample=0.7613664146909971; total time=   0.1s
# [CV] END colsample_bytree=0.8566223936114975, gamma=3.803925243084487, learning_rate=0.12225543951389925, max_depth=9, n_estimators=994, subsample=0.7613664146909971; total time=   0.1s
# [CV] END colsample_bytree=0.7542853455823514, gamma=4.537832369630465, learning_rate=0.059858445829774995, max_depth=6, n_estimators=724, subsample=0.5384899549143964; total time=   0.1s
# [CV] END colsample_bytree=0.6092202186084168, gamma=2.082549739351831, learning_rate=0.18665605178377367, max_depth=9, n_estimators=547, subsample=0.6781489190384875; total time=   0.0s
# [CV] END colsample_bytree=0.6092202186084168, gamma=2.082549739351831, learning_rate=0.18665605178377367, max_depth=9, n_estimators=547, subsample=0.6781489190384875; total time=   0.1s
# [CV] END colsample_bytree=0.668807585701814, gamma=4.714548519562596, learning_rate=0.07464058640415104, max_depth=10, n_estimators=432, subsample=0.7019180855290204; total time=   0.1s
# [CV] END colsample_bytree=0.5740434649766999, gamma=4.98870242524471, learning_rate=0.063356202855057, max_depth=4, n_estimators=841, subsample=0.7055185066591156; total time=   0.1s
# [CV] END colsample_bytree=0.5165253664502742, gamma=1.725356240133415, learning_rate=0.13687026894027277, max_depth=4, n_estimators=252, subsample=0.7447263801387816; total time=   0.1s
# [CV] END colsample_bytree=0.9015698781899479, gamma=2.351503172230192, learning_rate=0.2066846281789686, max_depth=8, n_estimators=1106, subsample=0.908215936609692; total time=   0.1s
# [CV] END colsample_bytree=0.6101205237827741, gamma=3.555747662190089, learning_rate=0.1719002092279431, max_depth=6, n_estimators=1063, subsample=0.5480882755457104; total time=   0.1s
# [CV] END colsample_bytree=0.970261632244802, gamma=1.9878601054376115, learning_rate=0.11355027010549602, max_depth=10, n_estimators=840, subsample=0.8378450585196404; total time=   0.2s
# [CV] END colsample_bytree=0.8629778394351197, gamma=4.485551299762886, learning_rate=0.18741728485302347, max_depth=10, n_estimators=872, subsample=0.8210158230771438; total time=   0.1s
# [CV] END colsample_bytree=0.5507357714330161, gamma=3.317508845540279, learning_rate=0.011012316769243738, max_depth=4, n_estimators=905, subsample=0.8459475988463466; total time=   0.2s
# [CV] END colsample_bytree=0.9320837825359516, gamma=1.1509263412077764, learning_rate=0.10983867597695046, max_depth=6, n_estimators=746, subsample=0.8842770071531545; total time=   0.1s
# [CV] END colsample_bytree=0.92650472773368, gamma=1.4722444603479286, learning_rate=0.08701954572038505, max_depth=9, n_estimators=360, subsample=0.6584610025781388; total time=   0.2s
# [CV] END colsample_bytree=0.6872700594236812, gamma=4.75357153204958, learning_rate=0.15639878836228102, max_depth=7, n_estimators=814, subsample=0.7229163764267956; total time=   0.1s
# [CV] END colsample_bytree=0.6999304858576277, gamma=0.23332831606807714, learning_rate=0.20475110376829186, max_depth=5, n_estimators=1075, subsample=0.7571172192068059; total time=   0.2s
# [CV] END colsample_bytree=0.8421165132560784, gamma=2.2007624686980067, learning_rate=0.03440764696895577, max_depth=10, n_estimators=1142, subsample=0.5866823267538861; total time=   0.3s
# [CV] END colsample_bytree=0.6404672548436904, gamma=2.7134804157912424, learning_rate=0.03818484499495253, max_depth=3, n_estimators=1056, subsample=0.9934434683002586; total time=   0.1s
# [CV] END colsample_bytree=0.8861223846483287, gamma=0.993578407670862, learning_rate=0.01110442342472048, max_depth=5, n_estimators=792, subsample=0.855670976374325; total time=   0.2s
# [CV] END colsample_bytree=0.864803089169032, gamma=3.1877873567760657, learning_rate=0.18744254851526532, max_depth=3, n_estimators=938, subsample=0.5597971229691509; total time=   0.1s
# [CV] END colsample_bytree=0.7137705091792748, gamma=0.12709563372047594, learning_rate=0.031578285398660894, max_depth=9, n_estimators=440, subsample=0.6571779905381634; total time=   0.7s
# [CV] END colsample_bytree=0.6101205237827741, gamma=3.555747662190089, learning_rate=0.1719002092279431, max_depth=6, n_estimators=1063, subsample=0.5480882755457104; total time=   0.1s
# [CV] END colsample_bytree=0.8676080596203861, gamma=1.0453581036885684, learning_rate=0.11828959476551316, max_depth=5, n_estimators=462, subsample=0.8299920230170895; total time=   0.1s
# [CV] END colsample_bytree=0.9486078789766634, gamma=4.502090285816652, learning_rate=0.1366202914546536, max_depth=11, n_estimators=432, subsample=0.6746047873063304; total time=   0.1s
# [CV] END colsample_bytree=0.5420699824975244, gamma=0.8081435704730688, learning_rate=0.18971083770541586, max_depth=6, n_estimators=453, subsample=0.5045985258083148; total time=   0.1s
# [CV] END colsample_bytree=0.8732457025590121, gamma=3.2481644952360735, learning_rate=0.1798446820988356, max_depth=3, n_estimators=839, subsample=0.7841543016677358; total time=   0.1s
# [CV] END colsample_bytree=0.9320837825359516, gamma=1.1509263412077764, learning_rate=0.10983867597695046, max_depth=6, n_estimators=746, subsample=0.8842770071531545; total time=   0.2s
# [CV] END colsample_bytree=0.6044593588076801, gamma=3.355717584120253, learning_rate=0.08172935625923278, max_depth=4, n_estimators=1185, subsample=0.8703843088771022; total time=   0.1s
# [CV] END colsample_bytree=0.5499874579090014, gamma=2.2962444598293357, learning_rate=0.07674172222780437, max_depth=10, n_estimators=863, subsample=0.8254442364744264; total time=   0.1s
# [CV] END colsample_bytree=0.7962072844310213, gamma=0.23225206359998862, learning_rate=0.1315089703802877, max_depth=7, n_estimators=1040, subsample=0.5325257964926398; total time=   0.2s
# [CV] END colsample_bytree=0.6955303037866204, gamma=0.9111804389403116, learning_rate=0.16107228206353053, max_depth=8, n_estimators=765, subsample=0.7733551396716398; total time=   0.1s
# [CV] END colsample_bytree=0.6955303037866204, gamma=0.9111804389403116, learning_rate=0.16107228206353053, max_depth=8, n_estimators=765, subsample=0.7733551396716398; total time=   0.1s
# [CV] END colsample_bytree=0.6626651653816322, gamma=1.9433864484474102, learning_rate=0.06426980635477918, max_depth=7, n_estimators=991, subsample=0.6783766633467947; total time=   0.2s
# [CV] END colsample_bytree=0.8861223846483287, gamma=0.993578407670862, learning_rate=0.01110442342472048, max_depth=5, n_estimators=792, subsample=0.855670976374325; total time=   0.3s
# [CV] END colsample_bytree=0.7137705091792748, gamma=0.12709563372047594, learning_rate=0.031578285398660894, max_depth=9, n_estimators=440, subsample=0.6571779905381634; total time=   0.3s
# [CV] END colsample_bytree=0.9534142207728771, gamma=1.3606612469231765, learning_rate=0.13953802410827248, max_depth=11, n_estimators=827, subsample=0.6762844281670846; total time=   0.2s
# [CV] END colsample_bytree=0.5740434649766999, gamma=4.98870242524471, learning_rate=0.063356202855057, max_depth=4, n_estimators=841, subsample=0.7055185066591156; total time=   0.1s
# [CV] END colsample_bytree=0.9015698781899479, gamma=2.351503172230192, learning_rate=0.2066846281789686, max_depth=8, n_estimators=1106, subsample=0.908215936609692; total time=   0.1s
# [CV] END colsample_bytree=0.6101205237827741, gamma=3.555747662190089, learning_rate=0.1719002092279431, max_depth=6, n_estimators=1063, subsample=0.5480882755457104; total time=   0.1s
# [CV] END colsample_bytree=0.9086111001006079, gamma=2.7760040579973118, learning_rate=0.1159301156712013, max_depth=4, n_estimators=1096, subsample=0.5465513839029497; total time=   0.2s
# [CV] END colsample_bytree=0.8259806297513003, gamma=1.121346547302799, learning_rate=0.15243584426950718, max_depth=3, n_estimators=597, subsample=0.6626998490796339; total time=   0.1s
# [CV] END colsample_bytree=0.5468373839140462, gamma=1.8385790152971677, learning_rate=0.06304047353634509, max_depth=8, n_estimators=429, subsample=0.6965488623333802; total time=   0.1s
# [CV] END colsample_bytree=0.9320837825359516, gamma=1.1509263412077764, learning_rate=0.10983867597695046, max_depth=6, n_estimators=746, subsample=0.8842770071531545; total time=   0.1s
# [CV] END colsample_bytree=0.5077283082644337, gamma=4.641592812938627, learning_rate=0.09563682966346286, max_depth=7, n_estimators=806, subsample=0.9818099885446264; total time=   0.0s
# [CV] END colsample_bytree=0.92650472773368, gamma=1.4722444603479286, learning_rate=0.08701954572038505, max_depth=9, n_estimators=360, subsample=0.6584610025781388; total time=   0.2s
# [CV] END colsample_bytree=0.5282057895135501, gamma=3.609993861334124, learning_rate=0.19771054180315006, max_depth=4, n_estimators=391, subsample=0.9961057796456088; total time=   0.0s
# [CV] END colsample_bytree=0.6999304858576277, gamma=0.23332831606807714, learning_rate=0.20475110376829186, max_depth=5, n_estimators=1075, subsample=0.7571172192068059; total time=   0.1s
# [CV] END colsample_bytree=0.9744427686266666, gamma=4.828160165372797, learning_rate=0.17167946962329225, max_depth=11, n_estimators=545, subsample=0.5488360570031919; total time=   0.1s
# [CV] END colsample_bytree=0.8421165132560784, gamma=2.2007624686980067, learning_rate=0.03440764696895577, max_depth=10, n_estimators=1142, subsample=0.5866823267538861; total time=   0.2s
# [CV] END colsample_bytree=0.5924272277627636, gamma=4.847923138822793, learning_rate=0.16502656467222293, max_depth=4, n_estimators=401, subsample=0.9474136752138245; total time=   0.0s
# [CV] END colsample_bytree=0.5924272277627636, gamma=4.847923138822793, learning_rate=0.16502656467222293, max_depth=4, n_estimators=401, subsample=0.9474136752138245; total time=   0.0s
# [CV] END colsample_bytree=0.7989499894055425, gamma=4.609371175115584, learning_rate=0.0276985004103839, max_depth=9, n_estimators=451, subsample=0.522613644455269; total time=   0.2s
# [CV] END colsample_bytree=0.8861223846483287, gamma=0.993578407670862, learning_rate=0.01110442342472048, max_depth=5, n_estimators=792, subsample=0.855670976374325; total time=   0.4s
# [CV] END colsample_bytree=0.7542853455823514, gamma=4.537832369630465, learning_rate=0.059858445829774995, max_depth=6, n_estimators=724, subsample=0.5384899549143964; total time=   0.2s
# [CV] END colsample_bytree=0.9534142207728771, gamma=1.3606612469231765, learning_rate=0.13953802410827248, max_depth=11, n_estimators=827, subsample=0.6762844281670846; total time=   0.1s
# [CV] END colsample_bytree=0.5324461235544908, gamma=1.2695770696717235, learning_rate=0.05937521256772024, max_depth=9, n_estimators=585, subsample=0.856135294962221; total time=   0.2s
# [CV] END colsample_bytree=0.8991725624922755, gamma=0.7535877198271473, learning_rate=0.11163975534814373, max_depth=5, n_estimators=859, subsample=0.6629794526009424; total time=   0.2s
# [CV] END colsample_bytree=0.9486078789766634, gamma=4.502090285816652, learning_rate=0.1366202914546536, max_depth=11, n_estimators=432, subsample=0.6746047873063304; total time=   0.0s
# [CV] END colsample_bytree=0.8629778394351197, gamma=4.485551299762886, learning_rate=0.18741728485302347, max_depth=10, n_estimators=872, subsample=0.8210158230771438; total time=   0.1s
# [CV] END colsample_bytree=0.8259806297513003, gamma=1.121346547302799, learning_rate=0.15243584426950718, max_depth=3, n_estimators=597, subsample=0.6626998490796339; total time=   0.1s
# [CV] END colsample_bytree=0.9460232775885566, gamma=3.1556931299863145, learning_rate=0.1689622607083297, max_depth=3, n_estimators=483, subsample=0.8344620298315498; total time=   0.0s
# [CV] END colsample_bytree=0.9320837825359516, gamma=1.1509263412077764, learning_rate=0.10983867597695046, max_depth=6, n_estimators=746, subsample=0.8842770071531545; total time=   0.1s
# [CV] END colsample_bytree=0.92650472773368, gamma=1.4722444603479286, learning_rate=0.08701954572038505, max_depth=9, n_estimators=360, subsample=0.6584610025781388; total time=   0.1s
# [CV] END colsample_bytree=0.848507870497634, gamma=3.5124204199355464, learning_rate=0.08189823024395103, max_depth=9, n_estimators=737, subsample=0.9050566973395904; total time=   0.1s
# [CV] END colsample_bytree=0.5282057895135501, gamma=3.609993861334124, learning_rate=0.19771054180315006, max_depth=4, n_estimators=391, subsample=0.9961057796456088; total time=   0.0s
# [CV] END colsample_bytree=0.5282057895135501, gamma=3.609993861334124, learning_rate=0.19771054180315006, max_depth=4, n_estimators=391, subsample=0.9961057796456088; total time=   0.0s
# [CV] END colsample_bytree=0.6999304858576277, gamma=0.23332831606807714, learning_rate=0.20475110376829186, max_depth=5, n_estimators=1075, subsample=0.7571172192068059; total time=   0.1s
# [CV] END colsample_bytree=0.7962072844310213, gamma=0.23225206359998862, learning_rate=0.1315089703802877, max_depth=7, n_estimators=1040, subsample=0.5325257964926398; total time=   0.2s
# [CV] END colsample_bytree=0.6955303037866204, gamma=0.9111804389403116, learning_rate=0.16107228206353053, max_depth=8, n_estimators=765, subsample=0.7733551396716398; total time=   0.1s
# [CV] END colsample_bytree=0.7989499894055425, gamma=4.609371175115584, learning_rate=0.0276985004103839, max_depth=9, n_estimators=451, subsample=0.522613644455269; total time=   0.3s
# [CV] END colsample_bytree=0.8950877702656028, gamma=3.029799873905057, learning_rate=0.19526017570266982, max_depth=11, n_estimators=227, subsample=0.9315517129377968; total time=   0.1s
# [CV] END colsample_bytree=0.864803089169032, gamma=3.1877873567760657, learning_rate=0.18744254851526532, max_depth=3, n_estimators=938, subsample=0.5597971229691509; total time=   0.1s
# [CV] END colsample_bytree=0.8566223936114975, gamma=3.803925243084487, learning_rate=0.12225543951389925, max_depth=9, n_estimators=994, subsample=0.7613664146909971; total time=   0.1s
# [CV] END colsample_bytree=0.7542853455823514, gamma=4.537832369630465, learning_rate=0.059858445829774995, max_depth=6, n_estimators=724, subsample=0.5384899549143964; total time=   0.1s
# [CV] END colsample_bytree=0.6092202186084168, gamma=2.082549739351831, learning_rate=0.18665605178377367, max_depth=9, n_estimators=547, subsample=0.6781489190384875; total time=   0.1s
# [CV] END colsample_bytree=0.6523906290790145, gamma=0.8232792657147087, learning_rate=0.11681788387508839, max_depth=7, n_estimators=424, subsample=0.5599326836668415; total time=   0.1s
# [CV] END colsample_bytree=0.5324461235544908, gamma=1.2695770696717235, learning_rate=0.05937521256772024, max_depth=9, n_estimators=585, subsample=0.856135294962221; total time=   0.1s
# [CV] END colsample_bytree=0.9928252270553004, gamma=1.2102763575575022, learning_rate=0.14442710948117574, max_depth=10, n_estimators=322, subsample=0.621079969138713; total time=   0.1s
# [CV] END colsample_bytree=0.8991725624922755, gamma=0.7535877198271473, learning_rate=0.11163975534814373, max_depth=5, n_estimators=859, subsample=0.6629794526009424; total time=   0.2s
# [CV] END colsample_bytree=0.9486078789766634, gamma=4.502090285816652, learning_rate=0.1366202914546536, max_depth=11, n_estimators=432, subsample=0.6746047873063304; total time=   0.1s
# [CV] END colsample_bytree=0.5507357714330161, gamma=3.317508845540279, learning_rate=0.011012316769243738, max_depth=4, n_estimators=905, subsample=0.8459475988463466; total time=   0.3s
# [CV] END colsample_bytree=0.5077283082644337, gamma=4.641592812938627, learning_rate=0.09563682966346286, max_depth=7, n_estimators=806, subsample=0.9818099885446264; total time=   0.1s
# [CV] END colsample_bytree=0.6044593588076801, gamma=3.355717584120253, learning_rate=0.08172935625923278, max_depth=4, n_estimators=1185, subsample=0.8703843088771022; total time=   0.1s
# [CV] END colsample_bytree=0.5499874579090014, gamma=2.2962444598293357, learning_rate=0.07674172222780437, max_depth=10, n_estimators=863, subsample=0.8254442364744264; total time=   0.1s
# [CV] END colsample_bytree=0.7962072844310213, gamma=0.23225206359998862, learning_rate=0.1315089703802877, max_depth=7, n_estimators=1040, subsample=0.5325257964926398; total time=   0.1s
# [CV] END colsample_bytree=0.7962072844310213, gamma=0.23225206359998862, learning_rate=0.1315089703802877, max_depth=7, n_estimators=1040, subsample=0.5325257964926398; total time=   0.3s
# [CV] END colsample_bytree=0.7989499894055425, gamma=4.609371175115584, learning_rate=0.0276985004103839, max_depth=9, n_estimators=451, subsample=0.522613644455269; total time=   0.1s
# [CV] END colsample_bytree=0.6626651653816322, gamma=1.9433864484474102, learning_rate=0.06426980635477918, max_depth=7, n_estimators=991, subsample=0.6783766633467947; total time=   0.2s
# [CV] END colsample_bytree=0.8950877702656028, gamma=3.029799873905057, learning_rate=0.19526017570266982, max_depth=11, n_estimators=227, subsample=0.9315517129377968; total time=   0.1s
# [CV] END colsample_bytree=0.811649063413779, gamma=1.654490124263246, learning_rate=0.02271167005720473, max_depth=9, n_estimators=773, subsample=0.6625916610133735; total time=   0.5s
# [CV] END colsample_bytree=0.6523906290790145, gamma=0.8232792657147087, learning_rate=0.11681788387508839, max_depth=7, n_estimators=424, subsample=0.5599326836668415; total time=   0.1s
# [CV] END colsample_bytree=0.5324461235544908, gamma=1.2695770696717235, learning_rate=0.05937521256772024, max_depth=9, n_estimators=585, subsample=0.856135294962221; total time=   0.1s
# [CV] END colsample_bytree=0.9928252270553004, gamma=1.2102763575575022, learning_rate=0.14442710948117574, max_depth=10, n_estimators=322, subsample=0.621079969138713; total time=   0.2s
# [CV] END colsample_bytree=0.970261632244802, gamma=1.9878601054376115, learning_rate=0.11355027010549602, max_depth=10, n_estimators=840, subsample=0.8378450585196404; total time=   0.1s
# [CV] END colsample_bytree=0.8676080596203861, gamma=1.0453581036885684, learning_rate=0.11828959476551316, max_depth=5, n_estimators=462, subsample=0.8299920230170895; total time=   0.1s
# [CV] END colsample_bytree=0.8629778394351197, gamma=4.485551299762886, learning_rate=0.18741728485302347, max_depth=10, n_estimators=872, subsample=0.8210158230771438; total time=   0.1s
# [CV] END colsample_bytree=0.8259806297513003, gamma=1.121346547302799, learning_rate=0.15243584426950718, max_depth=3, n_estimators=597, subsample=0.6626998490796339; total time=   0.1s
# [CV] END colsample_bytree=0.9460232775885566, gamma=3.1556931299863145, learning_rate=0.1689622607083297, max_depth=3, n_estimators=483, subsample=0.8344620298315498; total time=   0.1s
# [CV] END colsample_bytree=0.5077283082644337, gamma=4.641592812938627, learning_rate=0.09563682966346286, max_depth=7, n_estimators=806, subsample=0.9818099885446264; total time=   0.1s
# [CV] END colsample_bytree=0.6044593588076801, gamma=3.355717584120253, learning_rate=0.08172935625923278, max_depth=4, n_estimators=1185, subsample=0.8703843088771022; total time=   0.1s
# [CV] END colsample_bytree=0.5282057895135501, gamma=3.609993861334124, learning_rate=0.19771054180315006, max_depth=4, n_estimators=391, subsample=0.9961057796456088; total time=   0.1s
# [CV] END colsample_bytree=0.7962072844310213, gamma=0.23225206359998862, learning_rate=0.1315089703802877, max_depth=7, n_estimators=1040, subsample=0.5325257964926398; total time=   0.2s
# [CV] END colsample_bytree=0.8421165132560784, gamma=2.2007624686980067, learning_rate=0.03440764696895577, max_depth=10, n_estimators=1142, subsample=0.5866823267538861; total time=   0.3s
# [CV] END colsample_bytree=0.6404672548436904, gamma=2.7134804157912424, learning_rate=0.03818484499495253, max_depth=3, n_estimators=1056, subsample=0.9934434683002586; total time=   0.1s
# [CV] END colsample_bytree=0.8950877702656028, gamma=3.029799873905057, learning_rate=0.19526017570266982, max_depth=11, n_estimators=227, subsample=0.9315517129377968; total time=   0.0s
# [CV] END colsample_bytree=0.8950877702656028, gamma=3.029799873905057, learning_rate=0.19526017570266982, max_depth=11, n_estimators=227, subsample=0.9315517129377968; total time=   0.1s
# [CV] END colsample_bytree=0.864803089169032, gamma=3.1877873567760657, learning_rate=0.18744254851526532, max_depth=3, n_estimators=938, subsample=0.5597971229691509; total time=   0.1s
# [CV] END colsample_bytree=0.8566223936114975, gamma=3.803925243084487, learning_rate=0.12225543951389925, max_depth=9, n_estimators=994, subsample=0.7613664146909971; total time=   0.1s
# [CV] END colsample_bytree=0.7542853455823514, gamma=4.537832369630465, learning_rate=0.059858445829774995, max_depth=6, n_estimators=724, subsample=0.5384899549143964; total time=   0.1s
# [CV] END colsample_bytree=0.6448757264568841, gamma=0.8061064362700221, learning_rate=0.19593953046851464, max_depth=11, n_estimators=845, subsample=0.7282672852414551; total time=   0.1s
# [CV] END colsample_bytree=0.6448757264568841, gamma=0.8061064362700221, learning_rate=0.19593953046851464, max_depth=11, n_estimators=845, subsample=0.7282672852414551; total time=   0.1s
# [CV] END colsample_bytree=0.6523906290790145, gamma=0.8232792657147087, learning_rate=0.11681788387508839, max_depth=7, n_estimators=424, subsample=0.5599326836668415; total time=   0.1s
# [CV] END colsample_bytree=0.668807585701814, gamma=4.714548519562596, learning_rate=0.07464058640415104, max_depth=10, n_estimators=432, subsample=0.7019180855290204; total time=   0.1s
# [CV] END colsample_bytree=0.5165253664502742, gamma=1.725356240133415, learning_rate=0.13687026894027277, max_depth=4, n_estimators=252, subsample=0.7447263801387816; total time=   0.0s
# [CV] END colsample_bytree=0.9928252270553004, gamma=1.2102763575575022, learning_rate=0.14442710948117574, max_depth=10, n_estimators=322, subsample=0.621079969138713; total time=   0.0s
# [CV] END colsample_bytree=0.9015698781899479, gamma=2.351503172230192, learning_rate=0.2066846281789686, max_depth=8, n_estimators=1106, subsample=0.908215936609692; total time=   0.2s
# [CV] END colsample_bytree=0.970261632244802, gamma=1.9878601054376115, learning_rate=0.11355027010549602, max_depth=10, n_estimators=840, subsample=0.8378450585196404; total time=   0.1s
# [CV] END colsample_bytree=0.9486078789766634, gamma=4.502090285816652, learning_rate=0.1366202914546536, max_depth=11, n_estimators=432, subsample=0.6746047873063304; total time=   0.1s
# [CV] END colsample_bytree=0.5507357714330161, gamma=3.317508845540279, learning_rate=0.011012316769243738, max_depth=4, n_estimators=905, subsample=0.8459475988463466; total time=   0.2s
# [CV] END colsample_bytree=0.5218018858772169, gamma=4.972752553986705, learning_rate=0.10398890279818859, max_depth=7, n_estimators=717, subsample=0.6850793501277221; total time=   0.1s
# [CV] END colsample_bytree=0.92650472773368, gamma=1.4722444603479286, learning_rate=0.08701954572038505, max_depth=9, n_estimators=360, subsample=0.6584610025781388; total time=   0.1s
# [CV] END colsample_bytree=0.848507870497634, gamma=3.5124204199355464, learning_rate=0.08189823024395103, max_depth=9, n_estimators=737, subsample=0.9050566973395904; total time=   0.1s
# [CV] END colsample_bytree=0.6872700594236812, gamma=4.75357153204958, learning_rate=0.15639878836228102, max_depth=7, n_estimators=814, subsample=0.7229163764267956; total time=   0.1s
# [CV] END colsample_bytree=0.8087407548138583, gamma=3.0582658024414044, learning_rate=0.011413261043943482, max_depth=11, n_estimators=760, subsample=0.7623873301291946; total time=   0.2s
# [CV] END colsample_bytree=0.9744427686266666, gamma=4.828160165372797, learning_rate=0.17167946962329225, max_depth=11, n_estimators=545, subsample=0.5488360570031919; total time=   0.1s
# [CV] END colsample_bytree=0.8421165132560784, gamma=2.2007624686980067, learning_rate=0.03440764696895577, max_depth=10, n_estimators=1142, subsample=0.5866823267538861; total time=   0.4s
# [CV] END colsample_bytree=0.8861223846483287, gamma=0.993578407670862, learning_rate=0.01110442342472048, max_depth=5, n_estimators=792, subsample=0.855670976374325; total time=   0.4s
# [CV] END colsample_bytree=0.6448757264568841, gamma=0.8061064362700221, learning_rate=0.19593953046851464, max_depth=11, n_estimators=845, subsample=0.7282672852414551; total time=   0.1s
# [CV] END colsample_bytree=0.6092202186084168, gamma=2.082549739351831, learning_rate=0.18665605178377367, max_depth=9, n_estimators=547, subsample=0.6781489190384875; total time=   0.1s
# [CV] END colsample_bytree=0.6523906290790145, gamma=0.8232792657147087, learning_rate=0.11681788387508839, max_depth=7, n_estimators=424, subsample=0.5599326836668415; total time=   0.0s
# [CV] END colsample_bytree=0.668807585701814, gamma=4.714548519562596, learning_rate=0.07464058640415104, max_depth=10, n_estimators=432, subsample=0.7019180855290204; total time=   0.1s
# [CV] END colsample_bytree=0.5324461235544908, gamma=1.2695770696717235, learning_rate=0.05937521256772024, max_depth=9, n_estimators=585, subsample=0.856135294962221; total time=   0.1s
# [CV] END colsample_bytree=0.5740434649766999, gamma=4.98870242524471, learning_rate=0.063356202855057, max_depth=4, n_estimators=841, subsample=0.7055185066591156; total time=   0.2s
# [CV] END colsample_bytree=0.8991725624922755, gamma=0.7535877198271473, learning_rate=0.11163975534814373, max_depth=5, n_estimators=859, subsample=0.6629794526009424; total time=   0.2s
# [CV] END colsample_bytree=0.8676080596203861, gamma=1.0453581036885684, learning_rate=0.11828959476551316, max_depth=5, n_estimators=462, subsample=0.8299920230170895; total time=   0.1s
# [CV] END colsample_bytree=0.5420699824975244, gamma=0.8081435704730688, learning_rate=0.18971083770541586, max_depth=6, n_estimators=453, subsample=0.5045985258083148; total time=   0.1s
# [CV] END colsample_bytree=0.8259806297513003, gamma=1.121346547302799, learning_rate=0.15243584426950718, max_depth=3, n_estimators=597, subsample=0.6626998490796339; total time=   0.1s
# [CV] END colsample_bytree=0.8732457025590121, gamma=3.2481644952360735, learning_rate=0.1798446820988356, max_depth=3, n_estimators=839, subsample=0.7841543016677358; total time=   0.1s
# [CV] END colsample_bytree=0.9320837825359516, gamma=1.1509263412077764, learning_rate=0.10983867597695046, max_depth=6, n_estimators=746, subsample=0.8842770071531545; total time=   0.1s
# [CV] END colsample_bytree=0.5847463733430462, gamma=2.784006312291751, learning_rate=0.19723095483215622, max_depth=5, n_estimators=1071, subsample=0.535208065424772; total time=   0.1s
# [CV] END colsample_bytree=0.848507870497634, gamma=3.5124204199355464, learning_rate=0.08189823024395103, max_depth=9, n_estimators=737, subsample=0.9050566973395904; total time=   0.1s
# [CV] END colsample_bytree=0.6872700594236812, gamma=4.75357153204958, learning_rate=0.15639878836228102, max_depth=7, n_estimators=814, subsample=0.7229163764267956; total time=   0.1s
# [CV] END colsample_bytree=0.6999304858576277, gamma=0.23332831606807714, learning_rate=0.20475110376829186, max_depth=5, n_estimators=1075, subsample=0.7571172192068059; total time=   0.1s
# [CV] END colsample_bytree=0.9744427686266666, gamma=4.828160165372797, learning_rate=0.17167946962329225, max_depth=11, n_estimators=545, subsample=0.5488360570031919; total time=   0.1s
# [CV] END colsample_bytree=0.6955303037866204, gamma=0.9111804389403116, learning_rate=0.16107228206353053, max_depth=8, n_estimators=765, subsample=0.7733551396716398; total time=   0.1s
# [CV] END colsample_bytree=0.5924272277627636, gamma=4.847923138822793, learning_rate=0.16502656467222293, max_depth=4, n_estimators=401, subsample=0.9474136752138245; total time=   0.1s
# [CV] END colsample_bytree=0.6626651653816322, gamma=1.9433864484474102, learning_rate=0.06426980635477918, max_depth=7, n_estimators=991, subsample=0.6783766633467947; total time=   0.1s
# [CV] END colsample_bytree=0.6404672548436904, gamma=2.7134804157912424, learning_rate=0.03818484499495253, max_depth=3, n_estimators=1056, subsample=0.9934434683002586; total time=   0.2s
# [CV] END colsample_bytree=0.811649063413779, gamma=1.654490124263246, learning_rate=0.02271167005720473, max_depth=9, n_estimators=773, subsample=0.6625916610133735; total time=   0.4s
# [CV] END colsample_bytree=0.6448757264568841, gamma=0.8061064362700221, learning_rate=0.19593953046851464, max_depth=11, n_estimators=845, subsample=0.7282672852414551; total time=   0.1s
# [CV] END colsample_bytree=0.6523906290790145, gamma=0.8232792657147087, learning_rate=0.11681788387508839, max_depth=7, n_estimators=424, subsample=0.5599326836668415; total time=   0.2s
# [CV] END colsample_bytree=0.5740434649766999, gamma=4.98870242524471, learning_rate=0.063356202855057, max_depth=4, n_estimators=841, subsample=0.7055185066591156; total time=   0.1s
# [CV] END colsample_bytree=0.8991725624922755, gamma=0.7535877198271473, learning_rate=0.11163975534814373, max_depth=5, n_estimators=859, subsample=0.6629794526009424; total time=   0.1s
# [CV] END colsample_bytree=0.8676080596203861, gamma=1.0453581036885684, learning_rate=0.11828959476551316, max_depth=5, n_estimators=462, subsample=0.8299920230170895; total time=   0.1s
# [CV] END colsample_bytree=0.9086111001006079, gamma=2.7760040579973118, learning_rate=0.1159301156712013, max_depth=4, n_estimators=1096, subsample=0.5465513839029497; total time=   0.1s
# [CV] END colsample_bytree=0.5420699824975244, gamma=0.8081435704730688, learning_rate=0.18971083770541586, max_depth=6, n_estimators=453, subsample=0.5045985258083148; total time=   0.0s
# [CV] END colsample_bytree=0.5507357714330161, gamma=3.317508845540279, learning_rate=0.011012316769243738, max_depth=4, n_estimators=905, subsample=0.8459475988463466; total time=   0.1s
# [CV] END colsample_bytree=0.5468373839140462, gamma=1.8385790152971677, learning_rate=0.06304047353634509, max_depth=8, n_estimators=429, subsample=0.6965488623333802; total time=   0.0s
# [CV] END colsample_bytree=0.5468373839140462, gamma=1.8385790152971677, learning_rate=0.06304047353634509, max_depth=8, n_estimators=429, subsample=0.6965488623333802; total time=   0.1s
# [CV] END colsample_bytree=0.92650472773368, gamma=1.4722444603479286, learning_rate=0.08701954572038505, max_depth=9, n_estimators=360, subsample=0.6584610025781388; total time=   0.1s
# [CV] END colsample_bytree=0.6044593588076801, gamma=3.355717584120253, learning_rate=0.08172935625923278, max_depth=4, n_estimators=1185, subsample=0.8703843088771022; total time=   0.1s
# [CV] END colsample_bytree=0.848507870497634, gamma=3.5124204199355464, learning_rate=0.08189823024395103, max_depth=9, n_estimators=737, subsample=0.9050566973395904; total time=   0.1s

# %% [markdown]
# ---
# ## <span style="color:#ff5f27;">⏭️ **Next:** Part 04: Batch Inference</span>
#
# In the following notebook you will use your model for Batch Inference.
